# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def print_cumulative_mean_convergence(path_csv, print_csv=False):
    """
    Plotting the convergence of the cumulative mean for all columns in a CSV file.
    """
    df = pd.read_csv(path_csv)
    df = df.set_index('run number')

    for col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    # calculate cumulative mean 
    df_cumulative_mean = df.expanding().mean()
    df_cumulative_mean = df_cumulative_mean.rename(columns=lambda x: f'{x}_Cumulative_Mean')
    
    if print_csv:
        print(df_cumulative_mean)
        
    # exctracting last row = final mean
    final_means = df_cumulative_mean.iloc[-1]
    print(final_means.round(2))

    for column in df_cumulative_mean.columns:
        plt.plot(df_cumulative_mean.index, df_cumulative_mean[column], 
                label=column)
        
    plt.title('Convergence of the Cumulative Mean for All Columns')
    plt.xlabel('Run Number')
    plt.ylabel('Cumulative Mean Value')
    plt.legend(title='Column', loc='best')
    plt.plot()

# %%
print_cumulative_mean_convergence("./results/computation times/5x5-1_100k10k.csv")
# Out:
# GN_Cumulative_Mean        4.16
# AF_Cumulative_Mean        4.44
# Reach_Cumulative_Mean    22.28
# Name: 6, dtype: float64

# %%
print_cumulative_mean_convergence("./results/computation times/5x5-1_250k10k.csv")
# Out:
# GN_Cumulative_Mean        4.03
# AF_Cumulative_Mean        3.97
# Reach_Cumulative_Mean    61.28
# Name: 6, dtype: float64

# %%
print_cumulative_mean_convergence("./results/computation times/5x5-1_250k25k.csv")
# Out:
# GN_Cumulative_Mean       114.79
# AF_Cumulative_Mean       129.67
# Reach_Cumulative_Mean    139.38
# Name: 6, dtype: float64

# %%
print_cumulative_mean_convergence("./results/computation times/5x5-1_500k25k.csv", print_csv=False)
# Out:
# GN_Cumulative_Mean       217.13
# AF_Cumulative_Mean       215.94
# Reach_Cumulative_Mean    232.52
# Name: 7, dtype: float64

# %%
print_cumulative_mean_convergence("./results/computation times/5x5-1_500k50k.csv")
# Out:
# GN_Cumulative_Mean       200.69
# AF_Cumulative_Mean       184.94
# Reach_Cumulative_Mean    196.24
# Name: 6, dtype: float64

# %%
print_cumulative_mean_convergence("./results/computation times/5x5-1_1000k100k.csv")
# Out:
# GN_Cumulative_Mean       404.00
# AF_Cumulative_Mean       382.15
# Reach_Cumulative_Mean    501.19
# Name: 5, dtype: float64

# %%
print_cumulative_mean_convergence("./results/computation times/5x5-1_2000k200k.csv")
# Out:
# GN_Cumulative_Mean       1655.54
# AF_Cumulative_Mean       1148.35
# Reach_Cumulative_Mean     951.05
# Name: 5, dtype: float64

# %%
print_cumulative_mean_convergence("./results/computation times/5x5-1_5000k500k.csv")
# Out:
# GN_Cumulative_Mean       3231.70
# AF_Cumulative_Mean       3038.49
# Reach_Cumulative_Mean    2430.80
# Name: 6, dtype: float64

# %%
print_cumulative_mean_convergence("./results/computation times/5x5-1_firstnonzeroprobability_1k.csv")
# Out:
# GN_Cumulative_Mean       21200.0
# AF_Cumulative_Mean       18800.0
# Reach_Cumulative_Mean    14300.0
# Name: 10, dtype: float64

# %%
print_cumulative_mean_convergence("./results/computation times/5x5-1_firstnonzeroprobability_1k-comp_times.csv")
# Out:
# GN_Cumulative_Mean    9.04
# AF_Cumulative_Mean    8.10
# RH_Cumulative_Mean    6.29
# Name: 10, dtype: float64
